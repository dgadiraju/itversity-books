# %% [markdown]
# # Understanding Computer
#
# We will start the bootcamp by understanding our PC in detail. There are bunch of tools which can improve our productivity considerably.
#
# * Components of Computer
# * Operating systems
# * Linux based systems on Windows
# * Profile and Environment variables
# * Basic and Advanced editors
# * Software Engineering Lifecycle
# * Connecting to remote servers
# * Code Versioning and File Management Tools – Overview

# %% [markdown]
# ### Components of Computer
# Components of Computer can be broadly categorized into two – Hardware and Software.
#
# *Hardware Components*
#
# Let us start with Hardware Components.
#
# * **Memory** –  Good to have 8GB or 16GB RAM.
# * **CPU** – Processor can be dual core or quad core.Quad core has double the speed than dual core.16GB with quad core is an ideal combination.
# * **Storage** – Can be SSD or Hard disk.Storage doesn’t affect the performance.Data can be stored on cloud as well.
# * **Networking** – Better internet connectivity will ensure good performance.

# %% [markdown]
# ![](https://kaizen.itversity.com/wp-content/uploads/2018/03/01BareMetal.jpg)

# %% [markdown]
# ### Software Components
#
# Now let us talk briefly about software components.
#
# * Once we get hardware first we will install operating system.
# * At the lowest level, operating system is software which take instructions from us and work with hardware components to get us what we are looking for.
# * On top of OS, we will be installing application software.
#  * Browsers
#  * Media Players
#  * Editors
#  * and many more.
# * Some of the applications come as part of the Operating System itself while others need to be manually installed by us.
# * Here is the typical installation process for 3rd party applications (that might not come with Operating System)
#  * Download Software related to application
#  * Install the application
#  * Configure run time behavior
#  * Start and use application
#
# ### Operating systems
#
# Let us understand details with respect to operating systems.
#
# * Operating Systems can be used personally or for running applications. Here we will be primarily covering how to use laptops at work effectively to improve our productivity for day to day activities.
#  * Windows 7 or 8 or 10, Mac, Ubuntu Desktop etc are used for personal usage
#  * Windows NT or Server, Unix Flavors, RedHat Linux, Suse Linux are used for running applications. They are also knows as server operating systems.
# * Laptops you will get in your office will be either Windows based desktops or Mac based desktops. Some startups rely on Linux based ones.
#  * If permitted make sure you have latest stable versions of respective operating system in use. For example use Windows 10.
# * As part of this module we will see important tools related to Windows as well as Mac. Those who are using Linux based laptops can follow Mac based demos.
#
# ### Linux based systems on Windows
#
# Even though we develop using desktop operating systems such as Windows 10, applications will be deployed on server based operating systems (typically Linux flavor such as RedHat Linux, Suse Linux etc) and hence it is highly desired you have access to Linux based environment on your Windows based system.
#
# Here we will talk about how to setup Ubuntu using Windows Subsystem for Linux (a Ubuntu Linux based virtual machine on Windows 10)
#
# * If Subsystem for Linux is not available then you can use Virtual Box or VMWare Player/Workstation to setup virtual machines.
#  * If virtual machines are not allowed, then you can use Linux terminal emulator tools like Cygwin for some of the Linux based tasks for your applications.
#  * You can also use several GUI based tools to improve productivity to interact with remote servers from your PC.
#    * putty or some advanced SSH tools – to connect to remote servers
#    * Winscp or Filezilla – to copy files between your PC and servers
# * Some important terms
#  * Host – Physical Laptop
#  * Host Operating System – Main Operating System running on the host
#  * Guest – Virtual Machine(s) that are running on Host
#  * Guest Operating System – Operating System running on the Virtual Machine or Guest.
# * Open Windows Power Shell as an admin and run the below command. Enable-WindowsOptionalFeature -Online -FeatureName Microsoft-Windows-Subsystem-Linux
# * Now you can install the Linux distribution of your own choice. Preferred to use Ubuntu.
# * Click on Ubuntu distribution that launches the ubuntu terminal on windows.
# * Windows Subsystem for Linux is much tightly integrated virtual machine with host. It gives more flexibility than VMware and VM VirtualBox.
# * Give the username and password for Ubuntu. Once the setup is done use the commands <mark>ls -ltr</mark> and <mark>ls -altr</mark> to list out all the files.
# * The .profile and .bashrc files controls all the environment settings.
# * apt install is the command to download and install packages in ubuntu.
# * use apt help to get more detailed information about the command.
# * We can use ssh command to connect to remote server.
# * Ex: <mark>ssh username@hostname</mark> and give the password

# %% [markdown]
# ![](https://kaizen.itversity.com/wp-content/uploads/2018/03/04VirtualMachine.jpg)

# %% [markdown]
# ## Profile and Environment variables
# Once you login to the system, you will land into your desktop. Desktop is personalized entry point into a computer. You can change it as per your requirements using profile and environment variables.
#
# ***Setting environment variables in Linux***
#
# * Open either Mac or Linux terminal.This will take you to home directory.
# * Use the commands <mark>ls -altr</mark> to list out all the files, here you will see **.profile** and .bash_profile.  .profile is used by the user to have some specific settings for his own account.
# * The .profile and .bashrc files controls all the environment settings.
# * To set PATH in mac, open .profile and append to it – <mark>export PATH=/usr/local/jdk1.7.0/bin:$PATH</mark>
# * Never replace the contents of the path, always append to it.
#
# ***Setting environment variables in Windows***
#
# * Go to Environment Variables and then choose System Variables unless explicitly specified as part of instructions.
# * There are two types of environment variables  –  **_HOME** and **PATH**
# * **_HOME** is set to base directory of the application. Base directory is nothing but main directory into which files related to the software installed is copied.
# * The **PATH** is the system variable that your operating system uses to locate needed executables from the command line or Terminal window.
# * Executables will be typically under bin directory.
#
# ***Example***
#
# Let us download and install Java and understand what it actually mean. We will see both on Windows or Linux (if you are using Mac you can follow Linux instructions)
#
# * Make sure if Java is already installed on your PC – <mark>java -version</mark>
# * Search for JDK and download fro
# * Go to file explorer on Windows – C:\Program Files\Java\jdk
# * On the Advanced tab, select Environment Variables, and then edit JAVA_HOME to point to this location.
# * So, typically we will be setting JAVA_HOME to base directory which also has many sub-directories including bin directory.
# * We need to update PATH variable to bin directory to get executables to run.
# * Set the PATH environment variable if you want to be able to easily run the executables (javac.exe, java.exe, javadoc.exe etc.) from any directory without having to type the full path of the command. In case, the PATH variable is not set, you need to specify the full path to the executable every time you run it on terminal – C:\Java\jdk1.7.0\bin\javac MyClass.java
# * Now, try running javac from terminal after setting the PATH.
#
# In some cases installation will take care of updating global profiles and registries (in windows).We need not configure anything.
# * You can validate following these instructions
#  * <mark>echo $PATH</mark>– This will give you the directory path that is set in PATH variable. For Windows, you can say <mark>echo %PATH%</mark>
#  * <mark>which -ls</mark> – It returns the pathnames of the files which would be executed in the current environment (on Mac or Linux)
#
# ## Basic and Advanced editors
#
# Quite often we might have to edit some plain text files. Here are some of the tips related to editing text files.
#
# * People tend to use notepad or Microsoft Word for editing text files.
#  * Notepad is very primitive and it is counter productive.
#  * Microsoft Word is not for plain text, it is primarily to create files with images (images are not plain text)
# * Do not use notepad or Microsoft Word for text editing.
# * If it is code better to use IDEs (advanced editors and specific to programming languages)
# * If it is just plain text use standard text editors. Here are some of the features of standard text editors.
#  * Support for regular expressions
#  * Ability to edit files on remote servers
#  * Columnar Selection
#  * Macros – for replayable text editing
#  * Popular editors are – Notepad++, Ultraedit, Sublime Text
#
# We would highly recommend to choose Sublime Text or any one editor of your choice and be expert with it. It might take around 40 hours, but it will save thousands of hours in your career.
# * Depending on target servers we need to configure editors to save files in particular modes like DOS mode or unix mode.
#
# ## Software Engineering Lifecycle
#
# Let us get quick overview of Software Engineering Lifecycle – starting from requirement, to development and then all the way through making it available to the users of the application.
#
# * Requirements by Business Analyst
# * Application Design by Architect
# * ***Application Development by Development team (typically on their PC)***
# * Make code deployable (build archive of executables)
# * Release Management team push to Test environment
# * Application Testing by Test team
# * User acceptance test by BA or business users
# * Release Management team push to Prod environment
# * Make the application GA (generally available)
# * We use Waterfall or Agile methodology for the applications.
#
# ## Connecting to remote servers
#
# Now let us understand details related to connecting to remote servers.
#
# * Once the application is deployed in production, it will be supported by L1 support team.
# * Developers are considered as L3 support, if L1 support think that it is issue with respect to application then developers need to troubleshoot the issue.
#  * Troubleshoot the application failure by analysing logs
#  * Data related issues by running queries in the database or by reviewing the logic in the code.
# * Developers might have to connect to the production servers with restricted permissions to understand the problem and then reproduce it. Here are different alternatives using which developers can connect to remote servers.
#  * ssh tools
#  * putty or Cygwin on Windows 8 or earlier. Putty is primitive, better to use terminal or some advanced tools in Windows other than putty.
#  * Linux subsystem in Windows 10.
#  * Terminal on Mac/Linux
# * Keep in mind that once the source for the problem is identified, the issue should be reproduced locally and go through the entire life cycle to fix the issue.
#
# ## Code Versioning and File Management Tools – Overview
