# %% [markdown]
# # Development of Map Reduce APIs
# Let us develop our own Map Reduce APIs to understand how they work internally. We need to be comfortable with passing the functions as arguments.
#
# We will provide the code and walk you through to make you understand how the Map Reduce APIs are internally implemented.

# %% [markdown]
# ## Develop myFilter
#
# Develop a function by name myFilter which takes a collection and a function as arguments. Function should do the following:
# * Iterate through elements
# * Apply the condition using the argument passed. We might pass named function or lambda function.
# * Return the collection with all the elements satisfying the condition.

# %%
def myFilter(c, f):
    c_f = []
    for e in c:
        if(f(e)):
            c_f.append(e)
    return c_f

# %% [markdown]
# ## Validate myFilter function
#
# Use the same examples which were used before as part of Processing Collections using loops.
#
# * Read orders data

# %%
orders_path = "/data/retail_db/orders/part-00000"
orders = open(orders_path).read().splitlines()

# %% [markdown]
# * Get orders placed by customer id 12431

# %%
customer_orders = myFilter(orders, 
    lambda order: int(order.split(",")[2])==12431
    )

customer_orders
# Out:
# ['3774,2013-08-16 00:00:00.0,12431,CANCELED',
#  '3870,2013-08-17 00:00:00.0,12431,PENDING_PAYMENT',
#  '4032,2013-08-17 00:00:00.0,12431,ON_HOLD',
#  '22812,2013-12-12 00:00:00.0,12431,PENDING',
#  '22927,2013-12-13 00:00:00.0,12431,CLOSED',
#  '25614,2013-12-30 00:00:00.0,12431,CLOSED',
#  '27585,2014-01-12 00:00:00.0,12431,PROCESSING',
#  '28244,2014-01-15 00:00:00.0,12431,PENDING_PAYMENT',
#  '29109,2014-01-21 00:00:00.0,12431,ON_HOLD',
#  '29232,2014-01-21 00:00:00.0,12431,ON_HOLD',
#  '45894,2014-05-06 00:00:00.0,12431,CLOSED',
#  '46217,2014-05-07 00:00:00.0,12431,CLOSED',
#  '49678,2014-05-31 00:00:00.0,12431,PENDING',
#  '51865,2014-06-15 00:00:00.0,12431,PROCESSING',
#  '63146,2014-02-13 00:00:00.0,12431,PENDING_PAYMENT',
#  '67110,2014-07-14 00:00:00.0,12431,PENDING']

# %% [markdown]
# * Get orders placed by customer id 12431 in the month of 2014 January

# %%
customer_orders_for_month = myFilter(orders, 
    lambda order: int(order.split(",")[2])==12431 
    and order.split(",")[1].startswith("2014-01")
    )

customer_orders_for_month

# %%
def validate_orders(order, p_order_customer_id, p_order_month):
    order_splitted = order.split(',')
    order_customer_id = int(order_splitted[2])
    order_month = order_splitted[1][:7]
    return order_customer_id == p_order_customer_id and order_month == p_order_month

customer_orders_for_month = myFilter(orders, lambda order: validate_orders(order, 12431, '2014-01'))

customer_orders_for_month
# Out:
# ['27585,2014-01-12 00:00:00.0,12431,PROCESSING',
#  '28244,2014-01-15 00:00:00.0,12431,PENDING_PAYMENT',
#  '29109,2014-01-21 00:00:00.0,12431,ON_HOLD',
#  '29232,2014-01-21 00:00:00.0,12431,ON_HOLD']

# %% [markdown]
# * Get orders placed by customer id 12431 in processing or pending_payment for the month of 2014 January

# %%
customer_orders_for_month_pending = myFilter(orders, 
    lambda order: int(order.split(",")[2])==12431 
    and order.split(",")[1].startswith("2014-01")
    and order.split(",")[3] in ("PROCESSING", "PENDING_PAYMENT")
    )

customer_orders_for_month_pending
# Out:
# ['27585,2014-01-12 00:00:00.0,12431,PROCESSING',
#  '28244,2014-01-15 00:00:00.0,12431,PENDING_PAYMENT']

# %% [markdown]
# ## Develop myMap
#
# Develop a function by name myMap which takes a collection and a function as arguments. Function should do the following:
# * Iterate through elements
# * Apply the transformation logic using the argument passed.
# * Return the collection with all the elements which are transformed based on the logic passed.

# %%
def myMap(c, f):
    c_f = []
    for e in c:
        c_f.append(f(e))
    return c_f

# %% [markdown]
# ### Validate myMap function
# * Create list for range between 1 to 9 and return square of each number.

# %%
l = list(range(1, 10))
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
myMap(l, lambda e: e * e)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# * Use orders and extract order_dates. Also apply set and get only unique dates.

# %%
orders_path = "/data/retail_db/orders/part-00000"
orders = open(orders_path).read().splitlines()

order_dates = myMap(orders, 
    lambda order: order.split(",")[1]
    )

set(order_dates)

# %% [markdown]
# * Use orders and extract order_id as well as order_date from each element in the form of a tuple. Make sure that order_id is of type int.

# %%
t = (1, '2013-07-25')

# %%
orders_path = "/data/retail_db/orders/part-00000"
orders = open(orders_path).read().splitlines()

order_tuples = myMap(orders, 
    lambda order: (int(order.split(",")[0]), order.split(",")[1])
    )

order_tuples
# Out:
# [(1, '2013-07-25 00:00:00.0'),
#  (2, '2013-07-25 00:00:00.0'),
#  (3, '2013-07-25 00:00:00.0'),
#  (4, '2013-07-25 00:00:00.0'),
#  (5, '2013-07-25 00:00:00.0'),
#  (6, '2013-07-25 00:00:00.0'),
#  (7, '2013-07-25 00:00:00.0'),
#  (8, '2013-07-25 00:00:00.0'),
#  (9, '2013-07-25 00:00:00.0'),
#  (10, '2013-07-25 00:00:00.0'),
#  (11, '2013-07-25 00:00:00.0'),
#  (12, '2013-07-25 00:00:00.0'),
#  (13, '2013-07-25 00:00:00.0'),
#  (14, '2013-07-25 00:00:00.0'),
#  (15, '2013-07-25 00:00:00.0'),
#  (16, '2013-07-25 00:00:00.0'),
#  (17, '2013-07-25 00:00:00.0'),
#  (18, '2013-07-25 00:00:00.0'),
#  (19, '2013-07-25 00:00:00.0'),
#  (20, '2013-07-25 00:00:00.0'),
#  (21, '2013-07-25 00:00:00.0'),
#  (22, '2013-07-25 00:00:00.0'),
#  (23, '2013-07-25 00:00:00.0'),
#  (24, '2013-07-25 00:00:00.0'),
#  (25, '2013-07-25 00:00:00.0'),
#  (26, '2013-07-25 00:00:00.0'),
#  (27, '2013-07-25 00:00:00.0'),
#  (28, '2013-07-25 00:00:00.0'),
#  (29, '2013-07-25 00:00:00.0'),
#  (30, '2013-07-25 00:00:00.0'),
#  (31, '2013-07-25 00:00:00.0'),
#  (32, '2013-07-25 00:00:00.0'),
#  (33, '2013-07-25 00:00:00.0'),
#  (34, '2013-07-25 00:00:00.0'),
#  (35, '2013-07-25 00:00:00.0'),
#  (36, '2013-07-25 00:00:00.0'),
#  (37, '2013-07-25 00:00:00.0'),
#  (38, '2013-07-25 00:00:00.0'),
#  (39, '2013-07-25 00:00:00.0'),
#  (40, '2013-07-25 00:00:00.0'),
#  (41, '2013-07-25 00:00:00.0'),
#  (42, '2013-07-25 00:00:00.0'),
#  (43, '2013-07-25 00:00:00.0'),
#  (44, '2013-07-25 00:00:00.0'),
#  (45, '2013-07-25 00:00:00.0'),
#  (46, '2013-07-25 00:00:00.0'),
#  (47, '2013-07-25 00:00:00.0'),
#  (48, '2013-07-25 00:00:00.0'),
#  (49, '2013-07-25 00:00:00.0'),
#  (50, '2013-07-25 00:00:00.0'),
#  (51, '2013-07-25 00:00:00.0'),
#  (52, '2013-07-25 00:00:00.0'),
#  (53, '2013-07-25 00:00:00.0'),
#  (54, '2013-07-25 00:00:00.0'),
#  (55, '2013-07-25 00:00:00.0'),
#  (56, '2013-07-25 00:00:00.0'),
#  (57, '2013-07-25 00:00:00.0'),
#  (58, '2013-07-25 00:00:00.0'),
#  (59, '2013-07-25 00:00:00.0'),
#  (60, '2013-07-25 00:00:00.0'),
#  (61, '2013-07-25 00:00:00.0'),
#  (62, '2013-07-25 00:00:00.0'),
#  (63, '2013-07-25 00:00:00.0'),
#  (64, '2013-07-25 00:00:00.0'),
#  (65, '2013-07-25 00:00:00.0'),
#  (66, '2013-07-25 00:00:00.0'),
#  (67, '2013-07-25 00:00:00.0'),
#  (68, '2013-07-25 00:00:00.0'),
#  (69, '2013-07-25 00:00:00.0'),
#  (70, '2013-07-25 00:00:00.0'),
#  (71, '2013-07-25 00:00:00.0'),
#  (72, '2013-07-25 00:00:00.0'),
#  (73, '2013-07-25 00:00:00.0'),
#  (74, '2013-07-25 00:00:00.0'),
#  (75, '2013-07-25 00:00:00.0'),
#  (76, '2013-07-25 00:00:00.0'),
#  (77, '2013-07-25 00:00:00.0'),
#  (78, '2013-07-25 00:00:00.0'),
#  (79, '2013-07-25 00:00:00.0'),
#  (80, '2013-07-25 00:00:00.0'),
#  (81, '2013-07-25 00:00:00.0'),
#  (82, '2013-07-25 00:00:00.0'),
#  (83, '2013-07-25 00:00:00.0'),
#  (84, '2013-07-25 00:00:00.0'),
#  (85, '2013-07-25 00:00:00.0'),
#  (86, '2013-07-25 00:00:00.0'),
#  (87, '2013-07-25 00:00:00.0'),
#  (88, '2013-07-25 00:00:00.0'),
#  (89, '2013-07-25 00:00:00.0'),
#  (90, '2013-07-25 00:00:00.0'),
#  (91, '2013-07-25 00:00:00.0'),
#  (92, '2013-07-25 00:00:00.0'),
#  (93, '2013-07-25 00:00:00.0'),
#  (94, '2013-07-25 00:00:00.0'),
#  (95, '2013-07-25 00:00:00.0'),
#  (96, '2013-07-25 00:00:00.0'),
#  (97, '2013-07-25 00:00:00.0'),
#  (98, '2013-07-25 00:00:00.0'),
#  (99, '2013-07-25 00:00:00.0'),
#  (100, '2013-07-25 00:00:00.0'),
#  (101, '2013-07-25 00:00:00.0'),
#  (102, '2013-07-25 00:00:00.0'),
#  (103, '2013-07-25 00:00:00.0'),
#  (104, '2013-07-25 00:00:00.0'),
#  (105, '2013-07-26 00:00:00.0'),
#  (106, '2013-07-26 00:00:00.0'),
#  (107, '2013-07-26 00:00:00.0'),
#  (108, '2013-07-26 00:00:00.0'),
#  (109, '2013-07-26 00:00:00.0'),
#  (110, '2013-07-26 00:00:00.0'),
#  (111, '2013-07-26 00:00:00.0'),
#  (112, '2013-07-26 00:00:00.0'),
#  (113, '2013-07-26 00:00:00.0'),
#  (114, '2013-07-26 00:00:00.0'),
#  (115, '2013-07-26 00:00:00.0'),
#  (116, '2013-07-26 00:00:00.0'),
#  (117, '2013-07-26 00:00:00.0'),
#  (118, '2013-07-26 00:00:00.0'),
#  (119, '2013-07-26 00:00:00.0'),
#  (120, '2013-07-26 00:00:00.0'),
#  (121, '2013-07-26 00:00:00.0'),
#  (122, '2013-07-26 00:00:00.0'),
#  (123, '2013-07-26 00:00:00.0'),
#  (124, '2013-07-26 00:00:00.0'),
#  (125, '2013-07-26 00:00:00.0'),
#  (126, '2013-07-26 00:00:00.0'),
#  (127, '2013-07-26 00:00:00.0'),
#  (128, '2013-07-26 00:00:00.0'),
#  (129, '2013-07-26 00:00:00.0'),
#  (130, '2013-07-26 00:00:00.0'),
#  (131, '2013-07-26 00:00:00.0'),
#  (132, '2013-07-26 00:00:00.0'),
#  (133, '2013-07-26 00:00:00.0'),
#  (134, '2013-07-26 00:00:00.0'),
#  (135, '2013-07-26 00:00:00.0'),
#  (136, '2013-07-26 00:00:00.0'),
#  (137, '2013-07-26 00:00:00.0'),
#  (138, '2013-07-26 00:00:00.0'),
#  (139, '2013-07-26 00:00:00.0'),
#  (140, '2013-07-26 00:00:00.0'),
#  (141, '2013-07-26 00:00:00.0'),
#  (142, '2013-07-26 00:00:00.0'),
#  (143, '2013-07-26 00:00:00.0'),
#  (144, '2013-07-26 00:00:00.0'),
#  (145, '2013-07-26 00:00:00.0'),
#  (146, '2013-07-26 00:00:00.0'),
#  (147, '2013-07-26 00:00:00.0'),
#  (148, '2013-07-26 00:00:00.0'),
#  (149, '2013-07-26 00:00:00.0'),
#  (150, '2013-07-26 00:00:00.0'),
#  (151, '2013-07-26 00:00:00.0'),
#  (152, '2013-07-26 00:00:00.0'),
#  (153, '2013-07-26 00:00:00.0'),
#  (154, '2013-07-26 00:00:00.0'),
#  (155, '2013-07-26 00:00:00.0'),
#  (156, '2013-07-26 00:00:00.0'),
#  (157, '2013-07-26 00:00:00.0'),
#  (158, '2013-07-26 00:00:00.0'),
#  (159, '2013-07-26 00:00:00.0'),
#  (160, '2013-07-26 00:00:00.0'),
#  (161, '2013-07-26 00:00:00.0'),
#  (162, '2013-07-26 00:00:00.0'),
#  (163, '2013-07-26 00:00:00.0'),
#  (164, '2013-07-26 00:00:00.0'),
#  (165, '2013-07-26 00:00:00.0'),
#  (166, '2013-07-26 00:00:00.0'),
#  (167, '2013-07-26 00:00:00.0'),
#  (168, '2013-07-26 00:00:00.0'),
#  (169, '2013-07-26 00:00:00.0'),
#  (170, '2013-07-26 00:00:00.0'),
#  (171, '2013-07-26 00:00:00.0'),
#  (172, '2013-07-26 00:00:00.0'),
#  (173, '2013-07-26 00:00:00.0'),
#  (174, '2013-07-26 00:00:00.0'),
#  (175, '2013-07-26 00:00:00.0'),
#  (176, '2013-07-26 00:00:00.0'),
#  (177, '2013-07-26 00:00:00.0'),
#  (178, '2013-07-26 00:00:00.0'),
#  (179, '2013-07-26 00:00:00.0'),
#  (180, '2013-07-26 00:00:00.0'),
#  (181, '2013-07-26 00:00:00.0'),
#  (182, '2013-07-26 00:00:00.0'),
#  (183, '2013-07-26 00:00:00.0'),
#  (184, '2013-07-26 00:00:00.0'),
#  (185, '2013-07-26 00:00:00.0'),
#  (186, '2013-07-26 00:00:00.0'),
#  (187, '2013-07-26 00:00:00.0'),
#  (188, '2013-07-26 00:00:00.0'),
#  (189, '2013-07-26 00:00:00.0'),
#  (190, '2013-07-26 00:00:00.0'),
#  (191, '2013-07-26 00:00:00.0'),
#  (192, '2013-07-26 00:00:00.0'),
#  (193, '2013-07-26 00:00:00.0'),
#  (194, '2013-07-26 00:00:00.0'),
#  (195, '2013-07-26 00:00:00.0'),
#  (196, '2013-07-26 00:00:00.0'),
#  (197, '2013-07-26 00:00:00.0'),
#  (198, '2013-07-26 00:00:00.0'),
#  (199, '2013-07-26 00:00:00.0'),
#  (200, '2013-07-26 00:00:00.0'),
#  (201, '2013-07-26 00:00:00.0'),
#  (202, '2013-07-26 00:00:00.0'),
#  (203, '2013-07-26 00:00:00.0'),
#  (204, '2013-07-26 00:00:00.0'),
#  (205, '2013-07-26 00:00:00.0'),
#  (206, '2013-07-26 00:00:00.0'),
#  (207, '2013-07-26 00:00:00.0'),
#  (208, '2013-07-26 00:00:00.0'),
#  (209, '2013-07-26 00:00:00.0'),
#  (210, '2013-07-26 00:00:00.0'),
#  (211, '2013-07-26 00:00:00.0'),
#  (212, '2013-07-26 00:00:00.0'),
#  (213, '2013-07-26 00:00:00.0'),
#  (214, '2013-07-26 00:00:00.0'),
#  (215, '2013-07-26 00:00:00.0'),
#  (216, '2013-07-26 00:00:00.0'),
#  (217, '2013-07-26 00:00:00.0'),
#  (218, '2013-07-26 00:00:00.0'),
#  (219, '2013-07-26 00:00:00.0'),
#  (220, '2013-07-26 00:00:00.0'),
#  (221, '2013-07-26 00:00:00.0'),
#  (222, '2013-07-26 00:00:00.0'),
#  (223, '2013-07-26 00:00:00.0'),
#  (224, '2013-07-26 00:00:00.0'),
#  (225, '2013-07-26 00:00:00.0'),
#  (226, '2013-07-26 00:00:00.0'),
#  (227, '2013-07-26 00:00:00.0'),
#  (228, '2013-07-26 00:00:00.0'),
#  (229, '2013-07-26 00:00:00.0'),
#  (230, '2013-07-26 00:00:00.0'),
#  (231, '2013-07-26 00:00:00.0'),
#  (232, '2013-07-26 00:00:00.0'),
#  (233, '2013-07-26 00:00:00.0'),
#  (234, '2013-07-26 00:00:00.0'),
#  (235, '2013-07-26 00:00:00.0'),
#  (236, '2013-07-26 00:00:00.0'),
#  (237, '2013-07-26 00:00:00.0'),
#  (238, '2013-07-26 00:00:00.0'),
#  (239, '2013-07-26 00:00:00.0'),
#  (240, '2013-07-26 00:00:00.0'),
#  (241, '2013-07-26 00:00:00.0'),
#  (242, '2013-07-26 00:00:00.0'),
#  (243, '2013-07-26 00:00:00.0'),
#  (244, '2013-07-26 00:00:00.0'),
#  (245, '2013-07-26 00:00:00.0'),
#  (246, '2013-07-26 00:00:00.0'),
#  (247, '2013-07-26 00:00:00.0'),
#  (248, '2013-07-26 00:00:00.0'),
#  (249, '2013-07-26 00:00:00.0'),
#  (250, '2013-07-26 00:00:00.0'),
#  (251, '2013-07-26 00:00:00.0'),
#  (252, '2013-07-26 00:00:00.0'),
#  (253, '2013-07-26 00:00:00.0'),
#  (254, '2013-07-26 00:00:00.0'),
#  (255, '2013-07-26 00:00:00.0'),
#  (256, '2013-07-26 00:00:00.0'),
#  (257, '2013-07-26 00:00:00.0'),
#  (258, '2013-07-26 00:00:00.0'),
#  (259, '2013-07-26 00:00:00.0'),
#  (260, '2013-07-26 00:00:00.0'),
#  (261, '2013-07-26 00:00:00.0'),
#  (262, '2013-07-26 00:00:00.0'),
#  (263, '2013-07-26 00:00:00.0'),
#  (264, '2013-07-26 00:00:00.0'),
#  (265, '2013-07-26 00:00:00.0'),
#  (266, '2013-07-26 00:00:00.0'),
#  (267, '2013-07-26 00:00:00.0'),
#  (268, '2013-07-26 00:00:00.0'),
#  (269, '2013-07-26 00:00:00.0'),
#  (270, '2013-07-26 00:00:00.0'),
#  (271, '2013-07-26 00:00:00.0'),
#  (272, '2013-07-26 00:00:00.0'),
#  (273, '2013-07-26 00:00:00.0'),
#  (274, '2013-07-26 00:00:00.0'),
#  (275, '2013-07-26 00:00:00.0'),
#  (276, '2013-07-26 00:00:00.0'),
#  (277, '2013-07-26 00:00:00.0'),
#  (278, '2013-07-26 00:00:00.0'),
#  (279, '2013-07-26 00:00:00.0'),
#  (280, '2013-07-26 00:00:00.0'),
#  (281, '2013-07-26 00:00:00.0'),
#  (282, '2013-07-26 00:00:00.0'),
#  (283, '2013-07-26 00:00:00.0'),
#  (284, '2013-07-26 00:00:00.0'),
#  (285, '2013-07-26 00:00:00.0'),
#  (286, '2013-07-26 00:00:00.0'),
#  (287, '2013-07-26 00:00:00.0'),
#  (288, '2013-07-26 00:00:00.0'),
#  (289, '2013-07-26 00:00:00.0'),
#  (290, '2013-07-26 00:00:00.0'),
#  (291, '2013-07-26 00:00:00.0'),
#  (292, '2013-07-26 00:00:00.0'),
#  (293, '2013-07-26 00:00:00.0'),
#  (294, '2013-07-26 00:00:00.0'),
#  (295, '2013-07-26 00:00:00.0'),
#  (296, '2013-07-26 00:00:00.0'),
#  (297, '2013-07-26 00:00:00.0'),
#  (298, '2013-07-26 00:00:00.0'),
#  (299, '2013-07-26 00:00:00.0'),
#  (300, '2013-07-26 00:00:00.0'),
#  (301, '2013-07-26 00:00:00.0'),
#  (302, '2013-07-26 00:00:00.0'),
#  (303, '2013-07-26 00:00:00.0'),
#  (304, '2013-07-26 00:00:00.0'),
#  (305, '2013-07-26 00:00:00.0'),
#  (306, '2013-07-26 00:00:00.0'),
#  (307, '2013-07-26 00:00:00.0'),
#  (308, '2013-07-26 00:00:00.0'),
#  (309, '2013-07-26 00:00:00.0'),
#  (310, '2013-07-26 00:00:00.0'),
#  (311, '2013-07-26 00:00:00.0'),
#  (312, '2013-07-26 00:00:00.0'),
#  (313, '2013-07-26 00:00:00.0'),
#  (314, '2013-07-26 00:00:00.0'),
#  (315, '2013-07-26 00:00:00.0'),
#  (316, '2013-07-26 00:00:00.0'),
#  (317, '2013-07-26 00:00:00.0'),
#  (318, '2013-07-26 00:00:00.0'),
#  (319, '2013-07-26 00:00:00.0'),
#  (320, '2013-07-26 00:00:00.0'),
#  (321, '2013-07-26 00:00:00.0'),
#  (322, '2013-07-26 00:00:00.0'),
#  (323, '2013-07-26 00:00:00.0'),
#  (324, '2013-07-26 00:00:00.0'),
#  (325, '2013-07-26 00:00:00.0'),
#  (326, '2013-07-26 00:00:00.0'),
#  (327, '2013-07-26 00:00:00.0'),
#  (328, '2013-07-26 00:00:00.0'),
#  (329, '2013-07-26 00:00:00.0'),
#  (330, '2013-07-26 00:00:00.0'),
#  (331, '2013-07-26 00:00:00.0'),
#  (332, '2013-07-26 00:00:00.0'),
#  (333, '2013-07-26 00:00:00.0'),
#  (334, '2013-07-26 00:00:00.0'),
#  (335, '2013-07-26 00:00:00.0'),
#  (336, '2013-07-26 00:00:00.0'),
#  (337, '2013-07-26 00:00:00.0'),
#  (338, '2013-07-26 00:00:00.0'),
#  (339, '2013-07-26 00:00:00.0'),
#  (340, '2013-07-26 00:00:00.0'),
#  (341, '2013-07-26 00:00:00.0'),
#  (342, '2013-07-26 00:00:00.0'),
#  (343, '2013-07-26 00:00:00.0'),
#  (344, '2013-07-26 00:00:00.0'),
#  (345, '2013-07-26 00:00:00.0'),
#  (346, '2013-07-26 00:00:00.0'),
#  (347, '2013-07-27 00:00:00.0'),
#  (348, '2013-07-27 00:00:00.0'),
#  (349, '2013-07-27 00:00:00.0'),
#  (350, '2013-07-27 00:00:00.0'),
#  (351, '2013-07-27 00:00:00.0'),
#  (352, '2013-07-27 00:00:00.0'),
#  (353, '2013-07-27 00:00:00.0'),
#  (354, '2013-07-27 00:00:00.0'),
#  (355, '2013-07-27 00:00:00.0'),
#  (356, '2013-07-27 00:00:00.0'),
#  (357, '2013-07-27 00:00:00.0'),
#  (358, '2013-07-27 00:00:00.0'),
#  (359, '2013-07-27 00:00:00.0'),
#  (360, '2013-07-27 00:00:00.0'),
#  (361, '2013-07-27 00:00:00.0'),
#  (362, '2013-07-27 00:00:00.0'),
#  (363, '2013-07-27 00:00:00.0'),
#  (364, '2013-07-27 00:00:00.0'),
#  (365, '2013-07-27 00:00:00.0'),
#  (366, '2013-07-27 00:00:00.0'),
#  (367, '2013-07-27 00:00:00.0'),
#  (368, '2013-07-27 00:00:00.0'),
#  (369, '2013-07-27 00:00:00.0'),
#  (370, '2013-07-27 00:00:00.0'),
#  (371, '2013-07-27 00:00:00.0'),
#  (372, '2013-07-27 00:00:00.0'),
#  (373, '2013-07-27 00:00:00.0'),
#  (374, '2013-07-27 00:00:00.0'),
#  (375, '2013-07-27 00:00:00.0'),
#  (376, '2013-07-27 00:00:00.0'),
#  (377, '2013-07-27 00:00:00.0'),
#  (378, '2013-07-27 00:00:00.0'),
#  (379, '2013-07-27 00:00:00.0'),
#  (380, '2013-07-27 00:00:00.0'),
#  (381, '2013-07-27 00:00:00.0'),
#  (382, '2013-07-27 00:00:00.0'),
#  (383, '2013-07-27 00:00:00.0'),
#  (384, '2013-07-27 00:00:00.0'),
#  (385, '2013-07-27 00:00:00.0'),
#  (386, '2013-07-27 00:00:00.0'),
#  (387, '2013-07-27 00:00:00.0'),
#  (388, '2013-07-27 00:00:00.0'),
#  (389, '2013-07-27 00:00:00.0'),
#  (390, '2013-07-27 00:00:00.0'),
#  (391, '2013-07-27 00:00:00.0'),
#  (392, '2013-07-27 00:00:00.0'),
#  (393, '2013-07-27 00:00:00.0'),
#  (394, '2013-07-27 00:00:00.0'),
#  (395, '2013-07-27 00:00:00.0'),
#  (396, '2013-07-27 00:00:00.0'),
#  (397, '2013-07-27 00:00:00.0'),
#  (398, '2013-07-27 00:00:00.0'),
#  (399, '2013-07-27 00:00:00.0'),
#  (400, '2013-07-27 00:00:00.0'),
#  (401, '2013-07-27 00:00:00.0'),
#  (402, '2013-07-27 00:00:00.0'),
#  (403, '2013-07-27 00:00:00.0'),
#  (404, '2013-07-27 00:00:00.0'),
#  (405, '2013-07-27 00:00:00.0'),
#  (406, '2013-07-27 00:00:00.0'),
#  (407, '2013-07-27 00:00:00.0'),
#  (408, '2013-07-27 00:00:00.0'),
#  (409, '2013-07-27 00:00:00.0'),
#  (410, '2013-07-27 00:00:00.0'),
#  (411, '2013-07-27 00:00:00.0'),
#  (412, '2013-07-27 00:00:00.0'),
#  (413, '2013-07-27 00:00:00.0'),
#  (414, '2013-07-27 00:00:00.0'),
#  (415, '2013-07-27 00:00:00.0'),
#  (416, '2013-07-27 00:00:00.0'),
#  (417, '2013-07-27 00:00:00.0'),
#  (418, '2013-07-27 00:00:00.0'),
#  (419, '2013-07-27 00:00:00.0'),
#  (420, '2013-07-27 00:00:00.0'),
#  (421, '2013-07-27 00:00:00.0'),
#  (422, '2013-07-27 00:00:00.0'),
#  (423, '2013-07-27 00:00:00.0'),
#  (424, '2013-07-27 00:00:00.0'),
#  (425, '2013-07-27 00:00:00.0'),
#  (426, '2013-07-27 00:00:00.0'),
#  (427, '2013-07-27 00:00:00.0'),
#  (428, '2013-07-27 00:00:00.0'),
#  (429, '2013-07-27 00:00:00.0'),
#  (430, '2013-07-27 00:00:00.0'),
#  (431, '2013-07-27 00:00:00.0'),
#  (432, '2013-07-27 00:00:00.0'),
#  (433, '2013-07-27 00:00:00.0'),
#  (434, '2013-07-27 00:00:00.0'),
#  (435, '2013-07-27 00:00:00.0'),
#  (436, '2013-07-27 00:00:00.0'),
#  (437, '2013-07-27 00:00:00.0'),
#  (438, '2013-07-27 00:00:00.0'),
#  (439, '2013-07-27 00:00:00.0'),
#  (440, '2013-07-27 00:00:00.0'),
#  (441, '2013-07-27 00:00:00.0'),
#  (442, '2013-07-27 00:00:00.0'),
#  (443, '2013-07-27 00:00:00.0'),
#  (444, '2013-07-27 00:00:00.0'),
#  (445, '2013-07-27 00:00:00.0'),
#  (446, '2013-07-27 00:00:00.0'),
#  (447, '2013-07-27 00:00:00.0'),
#  (448, '2013-07-27 00:00:00.0'),
#  (449, '2013-07-27 00:00:00.0'),
#  (450, '2013-07-27 00:00:00.0'),
#  (451, '2013-07-27 00:00:00.0'),
#  (452, '2013-07-27 00:00:00.0'),
#  (453, '2013-07-27 00:00:00.0'),
#  (454, '2013-07-27 00:00:00.0'),
#  (455, '2013-07-27 00:00:00.0'),
#  (456, '2013-07-27 00:00:00.0'),
#  (457, '2013-07-27 00:00:00.0'),
#  (458, '2013-07-27 00:00:00.0'),
#  (459, '2013-07-27 00:00:00.0'),
#  (460, '2013-07-27 00:00:00.0'),
#  (461, '2013-07-27 00:00:00.0'),
#  (462, '2013-07-27 00:00:00.0'),
#  (463, '2013-07-27 00:00:00.0'),
#  (464, '2013-07-27 00:00:00.0'),
#  (465, '2013-07-27 00:00:00.0'),
#  (466, '2013-07-27 00:00:00.0'),
#  (467, '2013-07-27 00:00:00.0'),
#  (468, '2013-07-27 00:00:00.0'),
#  (469, '2013-07-27 00:00:00.0'),
#  (470, '2013-07-27 00:00:00.0'),
#  (471, '2013-07-27 00:00:00.0'),
#  (472, '2013-07-27 00:00:00.0'),
#  (473, '2013-07-27 00:00:00.0'),
#  (474, '2013-07-27 00:00:00.0'),
#  (475, '2013-07-27 00:00:00.0'),
#  (476, '2013-07-27 00:00:00.0'),
#  (477, '2013-07-27 00:00:00.0'),
#  (478, '2013-07-27 00:00:00.0'),
#  (479, '2013-07-27 00:00:00.0'),
#  (480, '2013-07-27 00:00:00.0'),
#  (481, '2013-07-27 00:00:00.0'),
#  (482, '2013-07-27 00:00:00.0'),
#  (483, '2013-07-27 00:00:00.0'),
#  (484, '2013-07-27 00:00:00.0'),
#  (485, '2013-07-27 00:00:00.0'),
#  (486, '2013-07-27 00:00:00.0'),
#  (487, '2013-07-27 00:00:00.0'),
#  (488, '2013-07-27 00:00:00.0'),
#  (489, '2013-07-27 00:00:00.0'),
#  (490, '2013-07-27 00:00:00.0'),
#  (491, '2013-07-27 00:00:00.0'),
#  (492, '2013-07-27 00:00:00.0'),
#  (493, '2013-07-27 00:00:00.0'),
#  (494, '2013-07-27 00:00:00.0'),
#  (495, '2013-07-27 00:00:00.0'),
#  (496, '2013-07-27 00:00:00.0'),
#  (497, '2013-07-27 00:00:00.0'),
#  (498, '2013-07-27 00:00:00.0'),
#  (499, '2013-07-27 00:00:00.0'),
#  (500, '2013-07-27 00:00:00.0'),
#  (501, '2013-07-27 00:00:00.0'),
#  (502, '2013-07-27 00:00:00.0'),
#  (503, '2013-07-27 00:00:00.0'),
#  (504, '2013-07-27 00:00:00.0'),
#  (505, '2013-07-27 00:00:00.0'),
#  (506, '2013-07-27 00:00:00.0'),
#  (507, '2013-07-27 00:00:00.0'),
#  (508, '2013-07-27 00:00:00.0'),
#  (509, '2013-07-27 00:00:00.0'),
#  (510, '2013-07-28 00:00:00.0'),
#  (511, '2013-07-28 00:00:00.0'),
#  (512, '2013-07-28 00:00:00.0'),
#  (513, '2013-07-28 00:00:00.0'),
#  (514, '2013-07-28 00:00:00.0'),
#  (515, '2013-07-28 00:00:00.0'),
#  (516, '2013-07-28 00:00:00.0'),
#  (517, '2013-07-28 00:00:00.0'),
#  (518, '2013-07-28 00:00:00.0'),
#  (519, '2013-07-28 00:00:00.0'),
#  (520, '2013-07-28 00:00:00.0'),
#  (521, '2013-07-28 00:00:00.0'),
#  (522, '2013-07-28 00:00:00.0'),
#  (523, '2013-07-28 00:00:00.0'),
#  (524, '2013-07-28 00:00:00.0'),
#  (525, '2013-07-28 00:00:00.0'),
#  (526, '2013-07-28 00:00:00.0'),
#  (527, '2013-07-28 00:00:00.0'),
#  (528, '2013-07-28 00:00:00.0'),
#  (529, '2013-07-28 00:00:00.0'),
#  (530, '2013-07-28 00:00:00.0'),
#  (531, '2013-07-28 00:00:00.0'),
#  (532, '2013-07-28 00:00:00.0'),
#  (533, '2013-07-28 00:00:00.0'),
#  (534, '2013-07-28 00:00:00.0'),
#  (535, '2013-07-28 00:00:00.0'),
#  (536, '2013-07-28 00:00:00.0'),
#  (537, '2013-07-28 00:00:00.0'),
#  (538, '2013-07-28 00:00:00.0'),
#  (539, '2013-07-28 00:00:00.0'),
#  (540, '2013-07-28 00:00:00.0'),
#  (541, '2013-07-28 00:00:00.0'),
#  (542, '2013-07-28 00:00:00.0'),
#  (543, '2013-07-28 00:00:00.0'),
#  (544, '2013-07-28 00:00:00.0'),
#  (545, '2013-07-28 00:00:00.0'),
#  (546, '2013-07-28 00:00:00.0'),
#  (547, '2013-07-28 00:00:00.0'),
#  (548, '2013-07-28 00:00:00.0'),
#  (549, '2013-07-28 00:00:00.0'),
#  (550, '2013-07-28 00:00:00.0'),
#  (551, '2013-07-28 00:00:00.0'),
#  (552, '2013-07-28 00:00:00.0'),
#  (553, '2013-07-28 00:00:00.0'),
#  (554, '2013-07-28 00:00:00.0'),
#  (555, '2013-07-28 00:00:00.0'),
#  (556, '2013-07-28 00:00:00.0'),
#  (557, '2013-07-28 00:00:00.0'),
#  (558, '2013-07-28 00:00:00.0'),
#  (559, '2013-07-28 00:00:00.0'),
#  (560, '2013-07-28 00:00:00.0'),
#  (561, '2013-07-28 00:00:00.0'),
#  (562, '2013-07-28 00:00:00.0'),
#  (563, '2013-07-28 00:00:00.0'),
#  (564, '2013-07-28 00:00:00.0'),
#  (565, '2013-07-28 00:00:00.0'),
#  (566, '2013-07-28 00:00:00.0'),
#  (567, '2013-07-28 00:00:00.0'),
#  (568, '2013-07-28 00:00:00.0'),
#  (569, '2013-07-28 00:00:00.0'),
#  (570, '2013-07-28 00:00:00.0'),
#  (571, '2013-07-28 00:00:00.0'),
#  (572, '2013-07-28 00:00:00.0'),
#  (573, '2013-07-28 00:00:00.0'),
#  (574, '2013-07-28 00:00:00.0'),
#  (575, '2013-07-28 00:00:00.0'),
#  (576, '2013-07-28 00:00:00.0'),
#  (577, '2013-07-28 00:00:00.0'),
#  (578, '2013-07-28 00:00:00.0'),
#  (579, '2013-07-28 00:00:00.0'),
#  (580, '2013-07-28 00:00:00.0'),
#  (581, '2013-07-28 00:00:00.0'),
#  (582, '2013-07-28 00:00:00.0'),
#  (583, '2013-07-28 00:00:00.0'),
#  (584, '2013-07-28 00:00:00.0'),
#  (585, '2013-07-28 00:00:00.0'),
#  (586, '2013-07-28 00:00:00.0'),
#  (587, '2013-07-28 00:00:00.0'),
#  (588, '2013-07-28 00:00:00.0'),
#  (589, '2013-07-28 00:00:00.0'),
#  (590, '2013-07-28 00:00:00.0'),
#  (591, '2013-07-28 00:00:00.0'),
#  (592, '2013-07-28 00:00:00.0'),
#  (593, '2013-07-28 00:00:00.0'),
#  (594, '2013-07-28 00:00:00.0'),
#  (595, '2013-07-28 00:00:00.0'),
#  (596, '2013-07-28 00:00:00.0'),
#  (597, '2013-07-28 00:00:00.0'),
#  (598, '2013-07-28 00:00:00.0'),
#  (599, '2013-07-28 00:00:00.0'),
#  (600, '2013-07-28 00:00:00.0'),
#  (601, '2013-07-28 00:00:00.0'),
#  (602, '2013-07-28 00:00:00.0'),
#  (603, '2013-07-28 00:00:00.0'),
#  (604, '2013-07-28 00:00:00.0'),
#  (605, '2013-07-28 00:00:00.0'),
#  (606, '2013-07-28 00:00:00.0'),
#  (607, '2013-07-28 00:00:00.0'),
#  (608, '2013-07-28 00:00:00.0'),
#  (609, '2013-07-28 00:00:00.0'),
#  (610, '2013-07-28 00:00:00.0'),
#  (611, '2013-07-28 00:00:00.0'),
#  (612, '2013-07-28 00:00:00.0'),
#  (613, '2013-07-28 00:00:00.0'),
#  (614, '2013-07-28 00:00:00.0'),
#  (615, '2013-07-28 00:00:00.0'),
#  (616, '2013-07-28 00:00:00.0'),
#  (617, '2013-07-28 00:00:00.0'),
#  (618, '2013-07-28 00:00:00.0'),
#  (619, '2013-07-28 00:00:00.0'),
#  (620, '2013-07-28 00:00:00.0'),
#  (621, '2013-07-28 00:00:00.0'),
#  (622, '2013-07-28 00:00:00.0'),
#  (623, '2013-07-28 00:00:00.0'),
#  (624, '2013-07-28 00:00:00.0'),
#  (625, '2013-07-28 00:00:00.0'),
#  (626, '2013-07-28 00:00:00.0'),
#  (627, '2013-07-28 00:00:00.0'),
#  (628, '2013-07-28 00:00:00.0'),
#  (629, '2013-07-28 00:00:00.0'),
#  (630, '2013-07-28 00:00:00.0'),
#  (631, '2013-07-28 00:00:00.0'),
#  (632, '2013-07-28 00:00:00.0'),
#  (633, '2013-07-28 00:00:00.0'),
#  (634, '2013-07-28 00:00:00.0'),
#  (635, '2013-07-28 00:00:00.0'),
#  (636, '2013-07-28 00:00:00.0'),
#  (637, '2013-07-28 00:00:00.0'),
#  (638, '2013-07-28 00:00:00.0'),
#  (639, '2013-07-28 00:00:00.0'),
#  (640, '2013-07-28 00:00:00.0'),
#  (641, '2013-07-28 00:00:00.0'),
#  (642, '2013-07-28 00:00:00.0'),
#  (643, '2013-07-28 00:00:00.0'),
#  (644, '2013-07-28 00:00:00.0'),
#  (645, '2013-07-28 00:00:00.0'),
#  (646, '2013-07-28 00:00:00.0'),
#  (647, '2013-07-28 00:00:00.0'),
#  (648, '2013-07-28 00:00:00.0'),
#  (649, '2013-07-28 00:00:00.0'),
#  (650, '2013-07-28 00:00:00.0'),
#  (651, '2013-07-28 00:00:00.0'),
#  (652, '2013-07-28 00:00:00.0'),
#  (653, '2013-07-28 00:00:00.0'),
#  (654, '2013-07-28 00:00:00.0'),
#  (655, '2013-07-28 00:00:00.0'),
#  (656, '2013-07-28 00:00:00.0'),
#  (657, '2013-07-28 00:00:00.0'),
#  (658, '2013-07-28 00:00:00.0'),
#  (659, '2013-07-28 00:00:00.0'),
#  (660, '2013-07-28 00:00:00.0'),
#  (661, '2013-07-28 00:00:00.0'),
#  (662, '2013-07-28 00:00:00.0'),
#  (663, '2013-07-28 00:00:00.0'),
#  (664, '2013-07-28 00:00:00.0'),
#  (665, '2013-07-28 00:00:00.0'),
#  (666, '2013-07-28 00:00:00.0'),
#  (667, '2013-07-28 00:00:00.0'),
#  (668, '2013-07-28 00:00:00.0'),
#  (669, '2013-07-28 00:00:00.0'),
#  (670, '2013-07-28 00:00:00.0'),
#  (671, '2013-07-28 00:00:00.0'),
#  (672, '2013-07-29 00:00:00.0'),
#  (673, '2013-07-29 00:00:00.0'),
#  (674, '2013-07-29 00:00:00.0'),
#  (675, '2013-07-29 00:00:00.0'),
#  (676, '2013-07-29 00:00:00.0'),
#  (677, '2013-07-29 00:00:00.0'),
#  (678, '2013-07-29 00:00:00.0'),
#  (679, '2013-07-29 00:00:00.0'),
#  (680, '2013-07-29 00:00:00.0'),
#  (681, '2013-07-29 00:00:00.0'),
#  (682, '2013-07-29 00:00:00.0'),
#  (683, '2013-07-29 00:00:00.0'),
#  (684, '2013-07-29 00:00:00.0'),
#  (685, '2013-07-29 00:00:00.0'),
#  (686, '2013-07-29 00:00:00.0'),
#  (687, '2013-07-29 00:00:00.0'),
#  (688, '2013-07-29 00:00:00.0'),
#  (689, '2013-07-29 00:00:00.0'),
#  (690, '2013-07-29 00:00:00.0'),
#  (691, '2013-07-29 00:00:00.0'),
#  (692, '2013-07-29 00:00:00.0'),
#  (693, '2013-07-29 00:00:00.0'),
#  (694, '2013-07-29 00:00:00.0'),
#  (695, '2013-07-29 00:00:00.0'),
#  (696, '2013-07-29 00:00:00.0'),
#  (697, '2013-07-29 00:00:00.0'),
#  (698, '2013-07-29 00:00:00.0'),
#  (699, '2013-07-29 00:00:00.0'),
#  (700, '2013-07-29 00:00:00.0'),
#  (701, '2013-07-29 00:00:00.0'),
#  (702, '2013-07-29 00:00:00.0'),
#  (703, '2013-07-29 00:00:00.0'),
#  (704, '2013-07-29 00:00:00.0'),
#  (705, '2013-07-29 00:00:00.0'),
#  (706, '2013-07-29 00:00:00.0'),
#  (707, '2013-07-29 00:00:00.0'),
#  (708, '2013-07-29 00:00:00.0'),
#  (709, '2013-07-29 00:00:00.0'),
#  (710, '2013-07-29 00:00:00.0'),
#  (711, '2013-07-29 00:00:00.0'),
#  (712, '2013-07-29 00:00:00.0'),
#  (713, '2013-07-29 00:00:00.0'),
#  (714, '2013-07-29 00:00:00.0'),
#  (715, '2013-07-29 00:00:00.0'),
#  (716, '2013-07-29 00:00:00.0'),
#  (717, '2013-07-29 00:00:00.0'),
#  (718, '2013-07-29 00:00:00.0'),
#  (719, '2013-07-29 00:00:00.0'),
#  (720, '2013-07-29 00:00:00.0'),
#  (721, '2013-07-29 00:00:00.0'),
#  (722, '2013-07-29 00:00:00.0'),
#  (723, '2013-07-29 00:00:00.0'),
#  (724, '2013-07-29 00:00:00.0'),
#  (725, '2013-07-29 00:00:00.0'),
#  (726, '2013-07-29 00:00:00.0'),
#  (727, '2013-07-29 00:00:00.0'),
#  (728, '2013-07-29 00:00:00.0'),
#  (729, '2013-07-29 00:00:00.0'),
#  (730, '2013-07-29 00:00:00.0'),
#  (731, '2013-07-29 00:00:00.0'),
#  (732, '2013-07-29 00:00:00.0'),
#  (733, '2013-07-29 00:00:00.0'),
#  (734, '2013-07-29 00:00:00.0'),
#  (735, '2013-07-29 00:00:00.0'),
#  (736, '2013-07-29 00:00:00.0'),
#  (737, '2013-07-29 00:00:00.0'),
#  (738, '2013-07-29 00:00:00.0'),
#  (739, '2013-07-29 00:00:00.0'),
#  (740, '2013-07-29 00:00:00.0'),
#  (741, '2013-07-29 00:00:00.0'),
#  (742, '2013-07-29 00:00:00.0'),
#  (743, '2013-07-29 00:00:00.0'),
#  (744, '2013-07-29 00:00:00.0'),
#  (745, '2013-07-29 00:00:00.0'),
#  (746, '2013-07-29 00:00:00.0'),
#  (747, '2013-07-29 00:00:00.0'),
#  (748, '2013-07-29 00:00:00.0'),
#  (749, '2013-07-29 00:00:00.0'),
#  (750, '2013-07-29 00:00:00.0'),
#  (751, '2013-07-29 00:00:00.0'),
#  (752, '2013-07-29 00:00:00.0'),
#  (753, '2013-07-29 00:00:00.0'),
#  (754, '2013-07-29 00:00:00.0'),
#  (755, '2013-07-29 00:00:00.0'),
#  (756, '2013-07-29 00:00:00.0'),
#  (757, '2013-07-29 00:00:00.0'),
#  (758, '2013-07-29 00:00:00.0'),
#  (759, '2013-07-29 00:00:00.0'),
#  (760, '2013-07-29 00:00:00.0'),
#  (761, '2013-07-29 00:00:00.0'),
#  (762, '2013-07-29 00:00:00.0'),
#  (763, '2013-07-29 00:00:00.0'),
#  (764, '2013-07-29 00:00:00.0'),
#  (765, '2013-07-29 00:00:00.0'),
#  (766, '2013-07-29 00:00:00.0'),
#  (767, '2013-07-29 00:00:00.0'),
#  (768, '2013-07-29 00:00:00.0'),
#  (769, '2013-07-29 00:00:00.0'),
#  (770, '2013-07-29 00:00:00.0'),
#  (771, '2013-07-29 00:00:00.0'),
#  (772, '2013-07-29 00:00:00.0'),
#  (773, '2013-07-29 00:00:00.0'),
#  (774, '2013-07-29 00:00:00.0'),
#  (775, '2013-07-29 00:00:00.0'),
#  (776, '2013-07-29 00:00:00.0'),
#  (777, '2013-07-29 00:00:00.0'),
#  (778, '2013-07-29 00:00:00.0'),
#  (779, '2013-07-29 00:00:00.0'),
#  (780, '2013-07-29 00:00:00.0'),
#  (781, '2013-07-29 00:00:00.0'),
#  (782, '2013-07-29 00:00:00.0'),
#  (783, '2013-07-29 00:00:00.0'),
#  (784, '2013-07-29 00:00:00.0'),
#  (785, '2013-07-29 00:00:00.0'),
#  (786, '2013-07-29 00:00:00.0'),
#  (787, '2013-07-29 00:00:00.0'),
#  (788, '2013-07-29 00:00:00.0'),
#  (789, '2013-07-29 00:00:00.0'),
#  (790, '2013-07-29 00:00:00.0'),
#  (791, '2013-07-29 00:00:00.0'),
#  (792, '2013-07-29 00:00:00.0'),
#  (793, '2013-07-29 00:00:00.0'),
#  (794, '2013-07-29 00:00:00.0'),
#  (795, '2013-07-29 00:00:00.0'),
#  (796, '2013-07-29 00:00:00.0'),
#  (797, '2013-07-29 00:00:00.0'),
#  (798, '2013-07-29 00:00:00.0'),
#  (799, '2013-07-29 00:00:00.0'),
#  (800, '2013-07-29 00:00:00.0'),
#  (801, '2013-07-29 00:00:00.0'),
#  (802, '2013-07-29 00:00:00.0'),
#  (803, '2013-07-29 00:00:00.0'),
#  (804, '2013-07-29 00:00:00.0'),
#  (805, '2013-07-29 00:00:00.0'),
#  (806, '2013-07-29 00:00:00.0'),
#  (807, '2013-07-29 00:00:00.0'),
#  (808, '2013-07-29 00:00:00.0'),
#  (809, '2013-07-29 00:00:00.0'),
#  (810, '2013-07-29 00:00:00.0'),
#  (811, '2013-07-29 00:00:00.0'),
#  (812, '2013-07-29 00:00:00.0'),
#  (813, '2013-07-29 00:00:00.0'),
#  (814, '2013-07-29 00:00:00.0'),
#  (815, '2013-07-29 00:00:00.0'),
#  (816, '2013-07-29 00:00:00.0'),
#  (817, '2013-07-29 00:00:00.0'),
#  (818, '2013-07-29 00:00:00.0'),
#  (819, '2013-07-29 00:00:00.0'),
#  (820, '2013-07-29 00:00:00.0'),
#  (821, '2013-07-29 00:00:00.0'),
#  (822, '2013-07-29 00:00:00.0'),
#  (823, '2013-07-29 00:00:00.0'),
#  (824, '2013-07-29 00:00:00.0'),
#  (825, '2013-07-29 00:00:00.0'),
#  (826, '2013-07-29 00:00:00.0'),
#  (827, '2013-07-29 00:00:00.0'),
#  (828, '2013-07-29 00:00:00.0'),
#  (829, '2013-07-29 00:00:00.0'),
#  (830, '2013-07-29 00:00:00.0'),
#  (831, '2013-07-29 00:00:00.0'),
#  (832, '2013-07-29 00:00:00.0'),
#  (833, '2013-07-29 00:00:00.0'),
#  (834, '2013-07-29 00:00:00.0'),
#  (835, '2013-07-29 00:00:00.0'),
#  (836, '2013-07-29 00:00:00.0'),
#  (837, '2013-07-29 00:00:00.0'),
#  (838, '2013-07-29 00:00:00.0'),
#  (839, '2013-07-29 00:00:00.0'),
#  (840, '2013-07-29 00:00:00.0'),
#  (841, '2013-07-29 00:00:00.0'),
#  (842, '2013-07-29 00:00:00.0'),
#  (843, '2013-07-29 00:00:00.0'),
#  (844, '2013-07-29 00:00:00.0'),
#  (845, '2013-07-29 00:00:00.0'),
#  (846, '2013-07-29 00:00:00.0'),
#  (847, '2013-07-29 00:00:00.0'),
#  (848, '2013-07-29 00:00:00.0'),
#  (849, '2013-07-29 00:00:00.0'),
#  (850, '2013-07-29 00:00:00.0'),
#  (851, '2013-07-29 00:00:00.0'),
#  (852, '2013-07-29 00:00:00.0'),
#  (853, '2013-07-29 00:00:00.0'),
#  (854, '2013-07-29 00:00:00.0'),
#  (855, '2013-07-29 00:00:00.0'),
#  (856, '2013-07-29 00:00:00.0'),
#  (857, '2013-07-29 00:00:00.0'),
#  (858, '2013-07-29 00:00:00.0'),
#  (859, '2013-07-29 00:00:00.0'),
#  (860, '2013-07-29 00:00:00.0'),
#  (861, '2013-07-29 00:00:00.0'),
#  (862, '2013-07-29 00:00:00.0'),
#  (863, '2013-07-29 00:00:00.0'),
#  (864, '2013-07-29 00:00:00.0'),
#  (865, '2013-07-29 00:00:00.0'),
#  (866, '2013-07-29 00:00:00.0'),
#  (867, '2013-07-29 00:00:00.0'),
#  (868, '2013-07-29 00:00:00.0'),
#  (869, '2013-07-29 00:00:00.0'),
#  (870, '2013-07-29 00:00:00.0'),
#  (871, '2013-07-29 00:00:00.0'),
#  (872, '2013-07-29 00:00:00.0'),
#  (873, '2013-07-29 00:00:00.0'),
#  (874, '2013-07-29 00:00:00.0'),
#  (875, '2013-07-29 00:00:00.0'),
#  (876, '2013-07-29 00:00:00.0'),
#  (877, '2013-07-29 00:00:00.0'),
#  (878, '2013-07-30 00:00:00.0'),
#  (879, '2013-07-30 00:00:00.0'),
#  (880, '2013-07-30 00:00:00.0'),
#  (881, '2013-07-30 00:00:00.0'),
#  (882, '2013-07-30 00:00:00.0'),
#  (883, '2013-07-30 00:00:00.0'),
#  (884, '2013-07-30 00:00:00.0'),
#  (885, '2013-07-30 00:00:00.0'),
#  (886, '2013-07-30 00:00:00.0'),
#  (887, '2013-07-30 00:00:00.0'),
#  (888, '2013-07-30 00:00:00.0'),
#  (889, '2013-07-30 00:00:00.0'),
#  (890, '2013-07-30 00:00:00.0'),
#  (891, '2013-07-30 00:00:00.0'),
#  (892, '2013-07-30 00:00:00.0'),
#  (893, '2013-07-30 00:00:00.0'),
#  (894, '2013-07-30 00:00:00.0'),
#  (895, '2013-07-30 00:00:00.0'),
#  (896, '2013-07-30 00:00:00.0'),
#  (897, '2013-07-30 00:00:00.0'),
#  (898, '2013-07-30 00:00:00.0'),
#  (899, '2013-07-30 00:00:00.0'),
#  (900, '2013-07-30 00:00:00.0'),
#  (901, '2013-07-30 00:00:00.0'),
#  (902, '2013-07-30 00:00:00.0'),
#  (903, '2013-07-30 00:00:00.0'),
#  (904, '2013-07-30 00:00:00.0'),
#  (905, '2013-07-30 00:00:00.0'),
#  (906, '2013-07-30 00:00:00.0'),
#  (907, '2013-07-30 00:00:00.0'),
#  (908, '2013-07-30 00:00:00.0'),
#  (909, '2013-07-30 00:00:00.0'),
#  (910, '2013-07-30 00:00:00.0'),
#  (911, '2013-07-30 00:00:00.0'),
#  (912, '2013-07-30 00:00:00.0'),
#  (913, '2013-07-30 00:00:00.0'),
#  (914, '2013-07-30 00:00:00.0'),
#  (915, '2013-07-30 00:00:00.0'),
#  (916, '2013-07-30 00:00:00.0'),
#  (917, '2013-07-30 00:00:00.0'),
#  (918, '2013-07-30 00:00:00.0'),
#  (919, '2013-07-30 00:00:00.0'),
#  (920, '2013-07-30 00:00:00.0'),
#  (921, '2013-07-30 00:00:00.0'),
#  (922, '2013-07-30 00:00:00.0'),
#  (923, '2013-07-30 00:00:00.0'),
#  (924, '2013-07-30 00:00:00.0'),
#  (925, '2013-07-30 00:00:00.0'),
#  (926, '2013-07-30 00:00:00.0'),
#  (927, '2013-07-30 00:00:00.0'),
#  (928, '2013-07-30 00:00:00.0'),
#  (929, '2013-07-30 00:00:00.0'),
#  (930, '2013-07-30 00:00:00.0'),
#  (931, '2013-07-30 00:00:00.0'),
#  (932, '2013-07-30 00:00:00.0'),
#  (933, '2013-07-30 00:00:00.0'),
#  (934, '2013-07-30 00:00:00.0'),
#  (935, '2013-07-30 00:00:00.0'),
#  (936, '2013-07-30 00:00:00.0'),
#  (937, '2013-07-30 00:00:00.0'),
#  (938, '2013-07-30 00:00:00.0'),
#  (939, '2013-07-30 00:00:00.0'),
#  (940, '2013-07-30 00:00:00.0'),
#  (941, '2013-07-30 00:00:00.0'),
#  (942, '2013-07-30 00:00:00.0'),
#  (943, '2013-07-30 00:00:00.0'),
#  (944, '2013-07-30 00:00:00.0'),
#  (945, '2013-07-30 00:00:00.0'),
#  (946, '2013-07-30 00:00:00.0'),
#  (947, '2013-07-30 00:00:00.0'),
#  (948, '2013-07-30 00:00:00.0'),
#  (949, '2013-07-30 00:00:00.0'),
#  (950, '2013-07-30 00:00:00.0'),
#  (951, '2013-07-30 00:00:00.0'),
#  (952, '2013-07-30 00:00:00.0'),
#  (953, '2013-07-30 00:00:00.0'),
#  (954, '2013-07-30 00:00:00.0'),
#  (955, '2013-07-30 00:00:00.0'),
#  (956, '2013-07-30 00:00:00.0'),
#  (957, '2013-07-30 00:00:00.0'),
#  (958, '2013-07-30 00:00:00.0'),
#  (959, '2013-07-30 00:00:00.0'),
#  (960, '2013-07-30 00:00:00.0'),
#  (961, '2013-07-30 00:00:00.0'),
#  (962, '2013-07-30 00:00:00.0'),
#  (963, '2013-07-30 00:00:00.0'),
#  (964, '2013-07-30 00:00:00.0'),
#  (965, '2013-07-30 00:00:00.0'),
#  (966, '2013-07-30 00:00:00.0'),
#  (967, '2013-07-30 00:00:00.0'),
#  (968, '2013-07-30 00:00:00.0'),
#  (969, '2013-07-30 00:00:00.0'),
#  (970, '2013-07-30 00:00:00.0'),
#  (971, '2013-07-30 00:00:00.0'),
#  (972, '2013-07-30 00:00:00.0'),
#  (973, '2013-07-30 00:00:00.0'),
#  (974, '2013-07-30 00:00:00.0'),
#  (975, '2013-07-30 00:00:00.0'),
#  (976, '2013-07-30 00:00:00.0'),
#  (977, '2013-07-30 00:00:00.0'),
#  (978, '2013-07-30 00:00:00.0'),
#  (979, '2013-07-30 00:00:00.0'),
#  (980, '2013-07-30 00:00:00.0'),
#  (981, '2013-07-30 00:00:00.0'),
#  (982, '2013-07-30 00:00:00.0'),
#  (983, '2013-07-30 00:00:00.0'),
#  (984, '2013-07-30 00:00:00.0'),
#  (985, '2013-07-30 00:00:00.0'),
#  (986, '2013-07-30 00:00:00.0'),
#  (987, '2013-07-30 00:00:00.0'),
#  (988, '2013-07-30 00:00:00.0'),
#  (989, '2013-07-30 00:00:00.0'),
#  (990, '2013-07-30 00:00:00.0'),
#  (991, '2013-07-30 00:00:00.0'),
#  (992, '2013-07-30 00:00:00.0'),
#  (993, '2013-07-30 00:00:00.0'),
#  (994, '2013-07-30 00:00:00.0'),
#  (995, '2013-07-30 00:00:00.0'),
#  (996, '2013-07-30 00:00:00.0'),
#  (997, '2013-07-30 00:00:00.0'),
#  (998, '2013-07-30 00:00:00.0'),
#  (999, '2013-07-30 00:00:00.0'),
#  (1000, '2013-07-30 00:00:00.0'),
#  ...]

# %%
len(orders)
# Out:
# 68883

# %%
len(order_tuples)
# Out:
# 68883

# %% [markdown]
# ## Develop myReduce
# Develop a function by name myReduce which takes a collection and a function as arguments. Function should do the following:
# * Iterate through elements
# * Perform aggregation operation using the argument passed. Argument should have necessary arithmetic logic.
# * Return the aggregated result.

# %%
l = [1, 4, 6, 2, 5]
l[1:]
# Out:
# [4, 6, 2, 5]

# %%
def myReduce(c, f):
    t = c[0]
    for e in c[1:]:
        t = f(t, e)
    return t

# %%
l = [2, 5, 3, 1, 4]

# %%
myReduce(l, lambda t, e: t + e)
# Out:
# 15

# %%
myReduce(l, lambda t, e: min(t, e))
# Out:
# 1

# %%
myReduce(l, lambda t, e: max(t, e))
# Out:
# 5

# %% [markdown]
# ## Develop myReduceByKey
# Develop a function by name myReduceByKey which takes a collection of tuples and a function as arguments. Each element in the collection should have exactly 2 attributes. Function should do the following:
# * Iterate through the collection of tuples.
# * Group the data by first element in the collection of tuples and apply the function using the argument passed. Argument should have necessary arithmetic logic.
# * Return a collection of tuples, where first element is unique and second element is aggregated result.

# %%
def myReduceByKey(p, f):
    p_f = {}
    for e in p:
        if(e[0] in p_f):
            p_f[e[0]] = f(p_f[e[0]], e[1])
        else:
            p_f[e[0]] = e[1]
    return list(p_f.items())

# %% [markdown]
# * Use the function to get the count by date from orders.

# %%
orders_path = "/data/retail_db/orders/part-00000"
orders = open(orders_path).read().splitlines()

order_tuples = myMap(orders, 
    lambda order: (order.split(",")[1], 1)
    )

order_tuples[:10]
# Out:
# [('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1),
#  ('2013-07-25 00:00:00.0', 1)]

# %%
order_count_by_date = myReduceByKey(order_tuples, lambda t, e: t + e)

# %%
order_count_by_date[:10]
# Out:
# [('2013-07-25 00:00:00.0', 143),
#  ('2013-07-26 00:00:00.0', 269),
#  ('2013-07-27 00:00:00.0', 202),
#  ('2013-07-28 00:00:00.0', 187),
#  ('2013-07-29 00:00:00.0', 253),
#  ('2013-07-30 00:00:00.0', 227),
#  ('2013-07-31 00:00:00.0', 252),
#  ('2013-08-01 00:00:00.0', 246),
#  ('2013-08-02 00:00:00.0', 224),
#  ('2013-08-03 00:00:00.0', 183)]

# %% [markdown]
# * Use the function to get the revenue for each order id.

# %%
order_items_path = "/data/retail_db/order_items/part-00000"
order_items = open(order_items_path).read().splitlines()

order_item_tuples = myMap(order_items, 
    lambda order_item: (int(order_item.split(",")[1]), float(order_item.split(",")[4]))
    )

order_item_tuples[:10]
# Out:
# [(1, 299.98),
#  (2, 199.99),
#  (2, 250.0),
#  (2, 129.99),
#  (4, 49.98),
#  (4, 299.95),
#  (4, 150.0),
#  (4, 199.92),
#  (5, 299.98),
#  (5, 299.95)]

# %%
revenue_per_order = myReduceByKey(order_item_tuples, lambda t, e: round(t + e, 2))

# %%
revenue_per_order

revenue_per_order[:10]
# Out:
# [(1, 299.98),
#  (2, 579.98),
#  (4, 699.85),
#  (5, 1129.86),
#  (7, 579.92),
#  (8, 729.84),
#  (9, 599.96),
#  (10, 651.92),
#  (11, 919.79),
#  (12, 1299.87)]

# %% [markdown]
# ## Exercises
# Here are the same exercises which you have solved before. Try to solve these using mapReduce APIs.
# * We will provide you a python script which will have all the above map reduce APIs. Use it as package and solve the below mentioned problems.
#   * Create a file with name `mymapreduce.py`
#   * Import and use it `from mymapreduce import *`.

# %%
def myFilter(c, f):
   c_f = []
   for e in c:
       if(f(e)):
           c_f.append(e)
   return c_f

def myMap(c, f):
   c_f = []
   for e in c:
       c_f.append(f(e))
   return c_f

def myReduce(c, f):
   t = c[0]
   for e in c[1:]:
       t = f(t, e)
   return t

def myReduceByKey(p, f):
   p_f = {}
   for e in p:
       if(e[0] in p_f):
           p_f[e[0]] = f(p_f[e[0]], e[1])
       else:
           p_f[e[0]] = e[1]
   return list(p_f.items())

# %% [markdown]
# * Get number of COMPLETE orders placed by each customer
# * Get total number of PENDING or PENDING_PAYMENT orders for the month of 2014 January.
# * Get outstanding amount for each month considering orders with status PAYMENT_REVIEW, PENDING, PENDING_PAYMENT and PROCESSING.
